# %%
#%% Selection of a model
from lazypredict.Supervised import LazyClassifier
from joblib import parallel_backend
from sklearn.model_selection import train_test_split
from toolbox.machine_learning import get_data, get_features_sets, balance_data
import warnings
warnings.filterwarnings('ignore')

period = [["2023-01-01 00:00:00" , "2023-01-14 23:00:00"]]
with parallel_backend('threading', n_jobs=4):
    features = {}
    features['simple'] = get_features_sets('simple')
    # Drop light_bulbs
    features['simple'].remove('lighting_bulbs')
    target = 'heat_stress_category'

    X, y = get_data('present-day', features['simple'], target, scaler=True, periods=period)

    # Balance data
    X, y = balance_data(X, y)

    # Print the number of samples for each class
    print('Number of samples for each class:\n {}'.format(y.value_counts()))
    print('Size of the dataset: {}'.format(len(y)))

    # Ask the user if he wants to continue
    input('Press any key to continue...')

    # Split data into train and test sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)

    clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
    models, predictions = clf.fit(X_train, X_test, y_train, y_test)
    print(models)

# Save models and predictions
models.to_csv('../results/models/ml_comparative_analysis.csv')
predictions.to_csv('../results/models/ml_comparative_analysis_predictions.csv')
# Out:
# Number of samples for each class:
#  0    49963
# 2    48153
# 1    45426
# 4    37630
# 3    23688
# Name: heat_stress_category, dtype: int64
# Size of the dataset: 204860
#  10%|█         | 3/29 [00:08<00:57,  2.22s/it]c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1c0da4938e0>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1c0da493ee0>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1c0da493a00>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
#  48%|████▊     | 14/29 [03:09<00:57,  3.84s/it]c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
#  52%|█████▏    | 15/29 [04:26<05:17, 22.71s/it]c:\Users\bruno\.conda\envs\ml-env\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1c0da4122c0>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# 100%|██████████| 29/29 [42:47<00:00, 88.52s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# BaggingClassifier                  0.86               0.85    None      0.86
# DecisionTreeClassifier             0.83               0.83    None      0.84
# RandomForestClassifier             0.81               0.81    None      0.81
# ExtraTreesClassifier               0.78               0.77    None      0.78
# XGBClassifier                      0.79               0.77    None      0.78
# ExtraTreeClassifier                0.73               0.73    None      0.73
# LGBMClassifier                     0.75               0.71    None      0.74
# KNeighborsClassifier               0.67               0.65    None      0.67
# SVC                                0.66               0.63    None      0.65
# NuSVC                              0.63               0.59    None      0.62
# QuadraticDiscriminantAnalysis      0.55               0.52    None      0.53
# CalibratedClassifierCV             0.56               0.51    None      0.52
# LinearSVC                          0.56               0.51    None      0.51
# LogisticRegression                 0.55               0.50    None      0.52
# LinearDiscriminantAnalysis         0.53               0.49    None      0.51
# RidgeClassifier                    0.54               0.49    None      0.48
# RidgeClassifierCV                  0.54               0.49    None      0.48
# AdaBoostClassifier                 0.53               0.49    None      0.49
# SGDClassifier                      0.51               0.47    None      0.46
# BernoulliNB                        0.48               0.44    None      0.44
# NearestCentroid                    0.47               0.44    None      0.44
# Perceptron                         0.48               0.44    None      0.45
# PassiveAggressiveClassifier        0.47               0.44    None      0.45
# GaussianNB                         0.46               0.43    None      0.43
# DummyClassifier                    0.24               0.20    None      0.09
#
#                                Time Taken
# Model
# BaggingClassifier                    1.74
# DecisionTreeClassifier               0.79
# RandomForestClassifier               4.06
# ExtraTreesClassifier                 4.90
# XGBClassifier                       12.41
# ExtraTreeClassifier                  0.30
# LGBMClassifier                       2.70
# KNeighborsClassifier                 8.07
# SVC                                763.50
# NuSVC                             1513.73
# QuadraticDiscriminantAnalysis        0.28
# CalibratedClassifierCV             165.62
# LinearSVC                           76.47
# LogisticRegression                   2.21
# LinearDiscriminantAnalysis           0.38
# RidgeClassifier                      0.21
# RidgeClassifierCV                    0.25
# AdaBoostClassifier                   6.95
# SGDClassifier                        0.47
# BernoulliNB                          0.22
# NearestCentroid                      0.23
# Perceptron                           0.33
# PassiveAggressiveClassifier          0.46
# GaussianNB                           0.26
# DummyClassifier                      0.16
